# %%
import fiddle.graphviz

from mlcast.config.base import training_experiment

cfg = training_experiment.as_buildable()

cfg.pl_module.network.num_blocks = 6
cfg.data.batch_size = 32

fiddle.graphviz.render(cfg)
